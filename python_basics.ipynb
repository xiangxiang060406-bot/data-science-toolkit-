# %% [markdown]
# <a href="https://colab.research.google.com/github/xiangxiang060406-bot/data-science-toolkit-/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to data science")
# Out:
# welcome to data science
